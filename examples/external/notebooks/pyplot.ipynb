# %% [markdown]
# # Pyplot tutorial
#
#
# An introduction to the pyplot interface (first time attempts):
# https://matplotlib.org/tutorials/introductory/lifecycle.html

# %%
import matplotlib.pyplot as plt

values = [1.0, 2.0, 3.0, 4.0]
plt.plot(values)

# %% [markdown]
# Show the difference in using Axes
#
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.axes.html

# %%
squared_values = [i**2 for i in values]

axes = plt.gca()

plt.plot(values)
axes.plot(squared_values)

# %% [markdown]
# https://matplotlib.org/gallery/subplots_axes_and_figures/subplots_demo.html

# %%
fig, ax = plt.subplots(nrows=1,ncols=2)
ax[0].plot(values)
ax[1].plot(squared_values)

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html

# %%
plt.plot(values, 'ro')
axes = plt.gca()
axes.plot(squared_values, 'gx')

# %% [markdown]
# https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.fill_between.html

# %%
fig, ax = plt.subplots(nrows=1,ncols=2)

ax[0].fill_between(values, squared_values)

ax[1].fill_between(values, values, squared_values)
ax[1].fill_between(values, [0 * len(values)], values)

# %% [markdown]
# Different plotting types:
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
import numpy as np

x_range = np.arange(0,9)
y_rand = np.random.randn(9)

plt.scatter(x_range, y_rand)

# %% [markdown]
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.polyfit.html
# https://data36.com/linear-regression-in-python-numpy-polyfit/

# %%
m, c = np.polyfit(x_range, y_rand, 1)

plt.scatter(x_range, y_rand)
plt.plot(x_range, (m*x_range)+c)

# %% [markdown]
# Managing the axis data:
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.axis.html

# %%
fig, ax = plt.subplots(nrows=1,ncols=2)
ax[0].plot(values, squared_values)
ax[0].set()
ax[1].plot(values, squared_values)
ax[1].set(xlim=[0, 6], ylim=[0, 20])
# Out:
# [(0.0, 20.0), (0.0, 6.0)]

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
